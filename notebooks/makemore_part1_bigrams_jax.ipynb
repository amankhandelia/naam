# %%
import pandas as pd
from histr import Shabdansh
from typing import List

# %%
def get_top_n_names(data_path: str = '../naam.csv', n:int=32000) -> List[str]:
    names = pd.read_csv(data_path)
    names['name'] = names['name'].map(Shabdansh)
    # remove names with only one syllable
    names = names[names['name'].map(len) > 1]
    names['is_valid_name'] = names['name'].apply(lambda name: all(map(Shabdansh.is_valid_cluster, list(name))))
    names = names[names['is_valid_name']]
    words = names.sort_values(by=['count'], ascending=False)['name'][:32000].tolist()
    return words

# %%
names = get_top_n_names()
# Out:
# /tmp/ipykernel_3235403/636747633.py:8: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   words = names.sort_values(by=['count'], ascending=False)['name'][:32000].tolist()

# %%
names[:50]
# Out:
# ['राम',
#  'पुत्र',
#  'राजेन्द्र',
#  'राजाराम',
#  'ओमप्रकाश',
#  'अब्दुल',
#  'छोटेलाल',
#  'सीताराम',
#  'जगदीश',
#  'राजेश',
#  'राधेश्याम',
#  'श्रीराम',
#  'सुरेश',
#  'अशोक',
#  'रमेश',
#  'रामप्रसाद',
#  'रामनाथ',
#  'राजकुमार',
#  'पत्नी',
#  'विजय',
#  'राकेश',
#  'सुरेन्द्र',
#  'बाबूराम',
#  'रामनरेश',
#  'रामलाल',
#  'शिव',
#  'महेन्द्र',
#  'दिनेश',
#  'रामचन्द्र',
#  'श्यामलाल',
#  'विनोद',
#  'विश्वनाथ',
#  'रामलखन',
#  'अनिल',
#  'रामपाल',
#  'रामकुमार',
#  'रामऔतार',
#  'रामदेव',
#  'रामदास',
#  'रामूप',
#  'बाबूलाल',
#  'संजय',
#  'कल्लू',
#  'हीरालाल',
#  'बैजनाथ',
#  'कमला',
#  'सियाराम',
#  'रामेश्वर',
#  'रामचन्दर',
#  'जगन्नाथ']

# %%
print(f"Min Syllable Count: {min(len(w) for w in names)}, Max Syllable Count: {max(len(w) for w in names)}")
# Out:
# Min Syllable Count: 2, Max Syllable Count: 10

# %%
b = {}
for w in names:
  chs = ['<S>'] + list(w) + ['<E>']
  for ch1, ch2 in zip(chs, chs[1:]):
    bigram = (ch1, ch2)
    b[bigram] = b.get(bigram, 0) + 1

# %%
sorted(b.items(), key = lambda kv: -kv[1])
# Out:
# [(('न', '<E>'), 3430),
#  (('ह', '<E>'), 3272),
#  (('र', '<E>'), 2900),
#  (('ल', '<E>'), 2397),
#  (('रा', 'म'), 2131),
#  (('सिं', 'ह'), 1944),
#  (('<S>', 'रा'), 1822),
#  (('<S>', 'अ'), 1661),
#  (('म', '<E>'), 1313),
#  (('<S>', 'स'), 1239),
#  (('ला', 'ल'), 1157),
#  (('सि', 'ह'), 1124),
#  (('द', '<E>'), 1108),
#  (('<S>', 'म'), 1018),
#  (('<S>', 'ज'), 860),
#  (('<S>', 'सु'), 832),
#  (('<S>', 'र'), 800),
#  (('<S>', 'ह'), 755),
#  (('पा', 'ल'), 732),
#  (('री', '<E>'), 730),
#  (('ली', '<E>'), 705),
#  (('<S>', 'ब'), 678),
#  (('<S>', 'वि'), 647),
#  (('<S>', 'क'), 643),
#  (('त', '<E>'), 635),
#  (('<S>', 'न'), 633),
#  (('<S>', 'मु'), 620),
#  (('श', '<E>'), 610),
#  (('रा', 'ज'), 555),
#  (('कु', 'मा'), 543),
#  (('ई', '<E>'), 536),
#  (('<S>', 'इ'), 521),
#  (('ती', '<E>'), 508),
#  (('ज', '<E>'), 497),
#  (('मा', 'र'), 495),
#  (('सा', 'द'), 489),
#  (('प्र', 'सा'), 477),
#  (('न्द्र', '<E>'), 449),
#  (('दी', 'न'), 441),
#  (('<S>', 'शि'), 434),
#  (('<S>', 'प'), 426),
#  (('रा', 'य'), 425),
#  (('र', 'न'), 422),
#  (('ना', 'थ'), 421),
#  (('थ', '<E>'), 421),
#  (('क', 'र'), 420),
#  (('या', '<E>'), 404),
#  (('अ', 'ली'), 403),
#  (('<S>', 'श'), 377),
#  (('<S>', 'व'), 377),
#  (('न्द', '<E>'), 373),
#  (('नी', '<E>'), 362),
#  (('र', 'सिं'), 361),
#  (('<S>', 'च'), 358),
#  (('य', 'न'), 356),
#  (('शि', 'व'), 355),
#  (('व', '<E>'), 351),
#  (('न', 'रा'), 347),
#  (('ह', 'र'), 345),
#  (('क', '<E>'), 336),
#  (('दे', 'व'), 333),
#  (('ना', '<E>'), 324),
#  (('ज', 'य'), 322),
#  (('द्दी', 'न'), 321),
#  (('च', 'न्द्र'), 318),
#  (('<S>', 'गु'), 313),
#  (('स', '<E>'), 305),
#  (('<S>', 'आ'), 295),
#  (('<S>', 'उ'), 294),
#  (('<S>', 'ल'), 291),
#  (('व', 'र'), 286),
#  (('न', 'सिं'), 286),
#  (('दु', 'र'), 284),
#  (('<S>', 'भ'), 279),
#  (('स', 'र'), 276),
#  (('<S>', 'सा'), 274),
#  (('ला', '<E>'), 271),
#  (('ह', 'म'), 270),
#  (('<S>', 'ग'), 268),
#  (('रा', '<E>'), 267),
#  (('म', 'द'), 265),
#  (('म', 'न'), 263),
#  (('ल', 'सिं'), 263),
#  (('हा', 'दु'), 253),
#  (('प', '<E>'), 251),
#  (('वी', 'र'), 250),
#  (('ब', 'हा'), 248),
#  (('र', 'सि'), 246),
#  (('<S>', 'कु'), 244),
#  (('च', 'न्द'), 243),
#  (('<S>', 'नि'), 238),
#  (('खां', '<E>'), 237),
#  (('<S>', 'बा'), 234),
#  (('<S>', 'बि'), 234),
#  (('<S>', 'द'), 233),
#  (('ण', '<E>'), 233),
#  (('व', 'ती'), 225),
#  (('<S>', 'सि'), 221),
#  (('श्व', 'र'), 220),
#  (('<S>', 'ध'), 220),
#  (('ल्ला', '<E>'), 220),
#  (('<S>', 'प्र'), 217),
#  (('<S>', 'मा'), 215),
#  (('अ', 'ह'), 214),
#  (('ज', 'ग'), 212),
#  (('न', 'न्द'), 212),
#  (('<S>', 'सो'), 209),
#  (('ता', '<E>'), 200),
#  (('<S>', 'दु'), 197),
#  (('<S>', 'दे'), 195),
#  (('<S>', 'मो'), 194),
#  (('र', 'म'), 194),
#  (('<S>', 'गो'), 190),
#  (('व', 'न'), 188),
#  (('ल', 'सि'), 188),
#  (('<S>', 'फ'), 186),
#  (('ता', 'प'), 185),
#  (('वा', '<E>'), 183),
#  (('<S>', 'बु'), 180),
#  (('प्र', 'ता'), 179),
#  (('र', 'त'), 174),
#  (('ज', 'न'), 174),
#  (('द', 'दी'), 173),
#  (('ह', 'रि'), 171),
#  (('शं', 'क'), 168),
#  (('मा', 'न'), 168),
#  (('ल्ला', 'ह'), 168),
#  (('न्द', 'र'), 167),
#  (('<S>', 'सू'), 167),
#  (('प', 'र'), 166),
#  (('जी', '<E>'), 165),
#  (('<S>', 'कि'), 165),
#  (('न', 'सि'), 164),
#  (('य', '<E>'), 163),
#  (('<S>', 'ला'), 162),
#  (('म', 'ह'), 162),
#  (('श्या', 'म'), 161),
#  (('शा', '<E>'), 161),
#  (('र', 'ज'), 159),
#  (('क', 'म'), 158),
#  (('मा', '<E>'), 158),
#  (('म', 'र'), 157),
#  (('ति', '<E>'), 157),
#  (('म', 'ल'), 156),
#  (('जी', 'त'), 156),
#  (('<S>', 'पु'), 155),
#  (('<S>', 'श्या'), 155),
#  (('मो', 'ह'), 154),
#  (('<S>', 'शा'), 149),
#  (('<S>', 'के'), 149),
#  (('न', 'ला'), 149),
#  (('रे', '<E>'), 147),
#  (('ब', '<E>'), 147),
#  (('श', 'कु'), 146),
#  (('के', 'श'), 145),
#  (('<S>', 'ना'), 145),
#  (('द', 'या'), 144),
#  (('<S>', 'वा'), 144),
#  (('रे', 'न्द्र'), 143),
#  (('का', 'श'), 142),
#  (('<S>', 'छ'), 142),
#  (('<S>', 'दि'), 141),
#  (('प्र', 'का'), 140),
#  (('<S>', 'त'), 140),
#  (('<S>', 'मि'), 139),
#  (('का', '<E>'), 138),
#  (('श', 'र'), 137),
#  (('<S>', 'रू'), 137),
#  (('<S>', 'बृ'), 135),
#  (('स', 'न'), 135),
#  (('प', 'ति'), 134),
#  (('ध', 'न'), 134),
#  (('<S>', 'जा'), 130),
#  (('र', 'अ'), 130),
#  (('<S>', 'का'), 128),
#  (('<S>', 'सं'), 126),
#  (('न्त', '<E>'), 126),
#  (('म', 'सिं'), 124),
#  (('ध', 'र'), 124),
#  (('द', 'त्त'), 124),
#  (('द', 'न'), 122),
#  (('<S>', 'ख'), 122),
#  (('स', 'म'), 122),
#  (('<S>', 'मं'), 120),
#  (('<S>', 'जि'), 119),
#  (('त्त', '<E>'), 118),
#  (('व', 'ल'), 117),
#  (('<S>', 'श्री'), 116),
#  (('कु', '<E>'), 116),
#  (('<S>', 'कृ'), 115),
#  (('रू', '<E>'), 115),
#  (('दा', '<E>'), 114),
#  (('सु', 'ख'), 114),
#  (('दा', 'र'), 113),
#  (('ब', 'र'), 113),
#  (('<S>', 'चि'), 113),
#  (('<S>', 'भू'), 112),
#  (('<S>', 'मे'), 110),
#  (('<S>', 'भु'), 110),
#  (('<S>', 'जु'), 110),
#  (('र', 'ण'), 109),
#  (('उ', 'द्दी'), 109),
#  (('ह', 'म्म'), 108),
#  (('सी', '<E>'), 108),
#  (('<S>', 'खु'), 108),
#  (('ना', 'रा'), 108),
#  (('म', 'सि'), 107),
#  (('जा', '<E>'), 106),
#  (('ह', 'न'), 105),
#  (('उ', 'द'), 105),
#  (('उ', 'ल्ला'), 105),
#  (('ब', 'ल'), 104),
#  (('वि', 'ज'), 103),
#  (('म', 'अ'), 103),
#  (('ह', 'स'), 103),
#  (('म्म', 'द'), 101),
#  (('<S>', 'ने'), 101),
#  (('रे', 'श'), 100),
#  (('ह', 'री'), 100),
#  (('श', 'न'), 100),
#  (('<S>', 'रि'), 100),
#  (('<S>', 'वी'), 99),
#  (('भा', 'न'), 99),
#  (('या', 'ल'), 99),
#  (('<S>', 'भा'), 99),
#  (('<S>', 'जै'), 99),
#  (('कृ', 'ष्ण'), 98),
#  (('म', 'स'), 98),
#  (('<S>', 'ओ'), 97),
#  (('नू', '<E>'), 97),
#  (('<S>', 'झ'), 97),
#  (('भ', 'ग'), 96),
#  (('अ', 'म'), 96),
#  (('ग', 'र'), 96),
#  (('अ', 'व'), 95),
#  (('<S>', 'गि'), 95),
#  (('<S>', 'ब्र'), 95),
#  (('लू', '<E>'), 94),
#  (('बी', 'र'), 94),
#  (('<S>', 'जो'), 94),
#  (('र', 'व'), 93),
#  (('नि', 'शा'), 93),
#  (('बा', 'ल'), 92),
#  (('ऊ', '<E>'), 92),
#  (('य', 'ण'), 92),
#  (('च', 'र'), 91),
#  (('न्द्र', 'प्र'), 91),
#  (('<S>', 'ता'), 91),
#  (('बी', '<E>'), 91),
#  (('ले', '<E>'), 91),
#  (('<S>', 'फु'), 91),
#  (('वे', 'न्द्र'), 90),
#  (('द', 'र'), 90),
#  (('रि', 'या'), 90),
#  (('बा', 'बू'), 89),
#  (('ने', 'श'), 88),
#  (('<S>', 'हु'), 87),
#  (('न्द्र', 'पा'), 86),
#  (('र', 'ना'), 86),
#  (('<S>', 'बे'), 86),
#  (('रा', 'जी'), 86),
#  (('र', 'पा'), 86),
#  (('न्द्र', 'कु'), 86),
#  (('दी', '<E>'), 85),
#  (('त', 'न'), 85),
#  (('प', 'त'), 85),
#  (('न्ती', '<E>'), 84),
#  (('हा', 'री'), 84),
#  (('<S>', 'हि'), 84),
#  (('दा', 'स'), 83),
#  (('र', 'मा'), 83),
#  (('र', 'वि'), 83),
#  (('न्द', 'न'), 83),
#  (('ल', 'ह'), 83),
#  (('ले', 'श'), 82),
#  (('दे', 'ई'), 82),
#  (('वा', 'न'), 81),
#  (('<S>', 'फू'), 81),
#  (('ग', 'न'), 81),
#  (('<S>', 'प्रे'), 80),
#  (('ख', 'न'), 79),
#  (('<S>', 'गं'), 79),
#  (('<S>', 'भो'), 79),
#  (('दी', 'प'), 79),
#  (('म', 'क'), 79),
#  (('च', 'न'), 79),
#  (('मु', 'ह'), 78),
#  (('श', 'च'), 78),
#  (('म', 'सु'), 78),
#  (('ख', '<E>'), 78),
#  (('प', 'सिं'), 78),
#  (('<S>', 'दी'), 77),
#  (('ल', 'म'), 77),
#  (('र', 'ब'), 77),
#  (('<S>', 'जी'), 76),
#  (('<S>', 'वृ'), 76),
#  (('मी', '<E>'), 76),
#  (('म', 'ला'), 75),
#  (('र', 'जा'), 75),
#  (('जे', 'न्द्र'), 74),
#  (('म', 'रा'), 74),
#  (('ब', 'द'), 74),
#  (('<S>', 'ते'), 74),
#  (('<S>', 'अं'), 74),
#  (('सु', 'रे'), 73),
#  (('अ', 'ज'), 73),
#  (('वि', 'न्द'), 73),
#  (('स', 'हा'), 73),
#  (('श्व', 'री'), 73),
#  (('न्द्र', 'सिं'), 73),
#  (('<S>', 'य'), 73),
#  (('म', 'हे'), 72),
#  (('म', 'च'), 72),
#  (('बू', '<E>'), 72),
#  (('इ', 'न्द्र'), 72),
#  (('कू', '<E>'), 72),
#  (('<S>', 'त्रि'), 72),
#  (('स', 'रा'), 72),
#  (('र', 'स'), 71),
#  (('प्रे', 'म'), 71),
#  (('की', '<E>'), 71),
#  (('फू', 'ल'), 71),
#  (('फ', '<E>'), 71),
#  (('ग', '<E>'), 71),
#  (('द', 'अ'), 71),
#  (('त', 'रा'), 70),
#  (('न', 'वी'), 70),
#  (('द', 'ल'), 70),
#  (('<S>', 'ए'), 70),
#  (('सि', 'हं'), 70),
#  (('हं', '<E>'), 70),
#  (('क', 'रा'), 69),
#  (('अ', 'न'), 69),
#  (('त', 'सिं'), 69),
#  (('क', 'ली'), 68),
#  (('रा', 'जे'), 67),
#  (('ओ', 'म'), 67),
#  (('ष', '<E>'), 67),
#  (('म', 'ब'), 67),
#  (('म', 'ती'), 67),
#  (('गी', '<E>'), 67),
#  (('म', 'हा'), 66),
#  (('श्री', '<E>'), 66),
#  (('श', 'म'), 66),
#  (('<S>', 'रु'), 66),
#  (('दे', 'बी'), 66),
#  (('न', 'नि'), 66),
#  (('म', 'प्र'), 65),
#  (('<S>', 'छो'), 65),
#  (('कि', 'शो'), 65),
#  (('<S>', 'रो'), 65),
#  (('द', 'य'), 65),
#  (('सू', 'र्य'), 65),
#  (('न', 'व'), 65),
#  (('न', 'क'), 65),
#  (('ल्ली', '<E>'), 65),
#  (('नि', 'या'), 65),
#  (('<S>', 'पा'), 64),
#  (('बृ', 'ज'), 64),
#  (('रू', 'प'), 64),
#  (('<S>', 'वे'), 64),
#  (('म', 'त'), 64),
#  (('से', 'न'), 64),
#  (('शा', 'ह'), 64),
#  (('र', 'घु'), 63),
#  (('री', 'ला'), 63),
#  (('रा', 'नी'), 63),
#  (('<S>', 'बी'), 63),
#  (('<S>', 'ई'), 63),
#  (('<S>', 'लो'), 63),
#  (('का', 'न्त'), 62),
#  (('गु', 'ला'), 62),
#  (('स', 'ह'), 62),
#  (('मं', 'ग'), 62),
#  (('<S>', 'शे'), 62),
#  (('का', 'र'), 62),
#  (('म', 'व'), 62),
#  (('<S>', 'ति'), 62),
#  (('<S>', 'भी'), 62),
#  (('मु', 'नी'), 62),
#  (('क्श', '<E>'), 62),
#  (('शु', 'न'), 61),
#  (('<S>', 'शी'), 61),
#  (('ल', 'क'), 61),
#  (('न', 'पा'), 61),
#  (('ल', 'व'), 61),
#  (('रू', 'ल'), 61),
#  (('सू', 'र'), 60),
#  (('न', 'वा'), 60),
#  (('धा', 'री'), 60),
#  (('द्र', '<E>'), 60),
#  (('र', 'मे'), 59),
#  (('मा', 'री'), 59),
#  (('सु', 'र'), 59),
#  (('न', 'रे'), 58),
#  (('गं', 'गा'), 58),
#  (('स', 'न्त'), 58),
#  (('गि', 'र'), 58),
#  (('र', 'द'), 58),
#  (('गु', 'र'), 58),
#  (('<S>', 'नौ'), 58),
#  (('ब', 'क्श'), 58),
#  (('र', 'खां'), 58),
#  (('जे', 'श'), 57),
#  (('मे', 'श'), 57),
#  (('ल', 'ख'), 57),
#  (('व', 'रा'), 57),
#  (('म', 'नि'), 57),
#  (('जा', 'न'), 57),
#  (('शी', '<E>'), 57),
#  (('न', 'र'), 57),
#  (('व', 'हा'), 57),
#  (('ह', 'क'), 57),
#  (('अ', 'र'), 56),
#  (('शो', 'र'), 55),
#  (('ब', 'ली'), 55),
#  (('र', 'ला'), 55),
#  (('<S>', 'ज्ञा'), 55),
#  (('न्नू', '<E>'), 55),
#  (('<S>', 'से'), 55),
#  (('<S>', 'दा'), 55),
#  (('क', 'ल'), 55),
#  (('प', 'ती'), 55),
#  (('ज', 'रा'), 54),
#  (('ल', 'ई'), 54),
#  (('ज', 'सिं'), 54),
#  (('<S>', 'वु'), 54),
#  (('इ', '<E>'), 54),
#  (('अ', 'ब्दु'), 53),
#  (('म', 'पा'), 53),
#  (('जू', '<E>'), 53),
#  (('स', 'त्य'), 53),
#  (('<S>', 'मै'), 53),
#  (('<S>', 'हो'), 53),
#  (('<S>', 'नी'), 53),
#  (('कि', 'श'), 53),
#  (('<S>', 'बं'), 53),
#  (('ह', 'मा'), 53),
#  (('रू', 'न'), 53),
#  (('<S>', 'कै'), 52),
#  (('गे', 'न्द्र'), 52),
#  (('जी', 'व'), 52),
#  (('<S>', 'तु'), 52),
#  (('शे', 'र'), 52),
#  (('ग', 'व'), 52),
#  (('न', 'सी'), 52),
#  (('म', 'उ'), 52),
#  (('रु', '<E>'), 52),
#  (('ज', 'ब'), 51),
#  (('ग', 'ल'), 51),
#  (('र', 'थ'), 51),
#  (('ल', 'च'), 51),
#  (('ख', 'र'), 51),
#  (('खी', '<E>'), 51),
#  (('<S>', 'नू'), 51),
#  (('स', 'री'), 51),
#  (('<S>', 'खे'), 51),
#  (('गु', 'ल'), 51),
#  (('न', 'कु'), 51),
#  (('स', 'त'), 51),
#  (('व', 'ली'), 51),
#  (('सा', '<E>'), 51),
#  (('ज', 'र'), 51),
#  (('सै', 'न'), 51),
#  (('न्द्र', 'सि'), 51),
#  (('ते', 'न्द्र'), 50),
#  (('श', 'व'), 50),
#  (('अ', 'जी'), 50),
#  (('र', 'प्र'), 50),
#  (('ह', 'ब'), 50),
#  (('लि', 'या'), 50),
#  (('म', 'णि'), 50),
#  (('तु', 'ल्ला'), 50),
#  (('खाँ', '<E>'), 50),
#  (('म', 'ना'), 49),
#  (('ता', 'र'), 49),
#  (('सि', 'या'), 49),
#  (('श', 'रा'), 49),
#  (('<S>', 'पं'), 49),
#  (('<S>', 'को'), 49),
#  (('<S>', 'चु'), 49),
#  (('ट', '<E>'), 49),
#  (('म्ब', 'र'), 49),
#  (('श', 'सिं'), 49),
#  (('क्स', '<E>'), 49),
#  (('ख्श', '<E>'), 49),
#  (('ल्लू', '<E>'), 48),
#  (('गा', '<E>'), 48),
#  (('र', 'दा'), 48),
#  (('<S>', 'पू'), 48),
#  (('गू', '<E>'), 48),
#  (('<S>', 'रे'), 48),
#  (('<S>', 'हा'), 48),
#  (('र', 'ह'), 48),
#  (('श', 'पा'), 48),
#  (('<S>', 'मौ'), 48),
#  (('<S>', 'सै'), 48),
#  (('र', 'क'), 48),
#  (('फु', 'ल'), 48),
#  (('म', 'जी'), 47),
#  (('क', 'ला'), 47),
#  (('कु', 'ल'), 47),
#  (('व', 'न्त'), 47),
#  (('र', 'वी'), 47),
#  (('दा', 'न'), 47),
#  (('ज', 'म'), 47),
#  (('न्द्र', 'ना'), 47),
#  (('मु', 'न'), 47),
#  (('चं', 'द्र'), 47),
#  (('म', 'कु'), 46),
#  (('<S>', 'बै'), 46),
#  (('गो', 'पा'), 46),
#  (('ज', 'स'), 46),
#  (('<S>', 'हे'), 46),
#  (('र', 'जी'), 46),
#  (('अ', 'नु'), 46),
#  (('<S>', 'शु'), 46),
#  (('न', 'प्र'), 46),
#  (('र', 'प'), 46),
#  (('त', 'सि'), 46),
#  (('जि', 'या'), 45),
#  (('ते', 'ज'), 45),
#  (('खा', '<E>'), 45),
#  (('मु', 'द्दी'), 45),
#  (('णि', '<E>'), 45),
#  (('र', 'ई'), 45),
#  (('<S>', 'छि'), 45),
#  (('त्ती', '<E>'), 45),
#  (('त', 'अ'), 45),
#  (('शां', '<E>'), 45),
#  (('ब्दु', 'ल'), 44),
#  (('न्नी', '<E>'), 44),
#  (('वा', 'री'), 44),
#  (('अ', 'मी'), 44),
#  (('इ', 'स'), 44),
#  (('व', 'सिं'), 44),
#  (('स', 'द'), 44),
#  (('ति', 'या'), 44),
#  (('खॉ', '<E>'), 44),
#  (('ज', 'ना'), 43),
#  (('ज', 'मु'), 43),
#  (('ल', 'कु'), 43),
#  (('न', 'ई'), 43),
#  (('<S>', 'झु'), 43),
#  (('चं', 'द'), 43),
#  (('रा', 'जा'), 42),
#  (('<S>', 'घ'), 42),
#  (('न्ना', '<E>'), 42),
#  (('ही', '<E>'), 42),
#  (('रा', 'मा'), 42),
#  (('ल', 'रा'), 42),
#  (('अ', 'स'), 42),
#  (('व', 'त'), 42),
#  (('प', 'न'), 42),
#  (('नि', '<E>'), 42),
#  (('र', 'ता'), 42),
#  (('<S>', 'पो'), 42),
#  (('ज', 'अ'), 42),
#  (('म', 'दे'), 41),
#  (('ला', 'श'), 41),
#  (('ग', 'वा'), 41),
#  (('तु', 'ल'), 41),
#  (('बि', 'हा'), 41),
#  (('न', 'न'), 41),
#  (('<S>', 'मू'), 41),
#  (('न्द्र', 'ब'), 41),
#  (('ग', 'रा'), 41),
#  (('ह', 'रा'), 41),
#  (('र', 'ही'), 41),
#  (('ल', 'वा'), 41),
#  (('श', 'क'), 41),
#  (('स', 'ला'), 41),
#  (('क', 'अ'), 41),
#  (('व', 'सि'), 41),
#  (('व', 'क'), 40),
#  (('गो', 'वि'), 40),
#  (('मा', 'ता'), 40),
#  (('त', 'ला'), 40),
#  (('म', 'रू'), 40),
#  (('ग', 'त'), 40),
#  (('<S>', 'या'), 40),
#  (('सा', 'ह'), 40),
#  (('<S>', 'झि'), 40),
#  (('<S>', 'कौ'), 40),
#  (('रा', 'व'), 40),
#  (('री', 'श'), 40),
#  (('<S>', 'कुं'), 40),
#  (('क', 'न'), 40),
#  (('मे', 'श्व'), 39),
#  (('वा', 'स'), 39),
#  (('हा', 'य'), 39),
#  (('र', 'ती'), 39),
#  (('कि', 'र'), 39),
#  (('अ', 'भि'), 39),
#  (('श', 'री'), 39),
#  (('भ', 'व'), 39),
#  (('क', 'त'), 39),
#  (('मी', 'र'), 39),
#  (('त', 'म'), 39),
#  (('<S>', 'नै'), 39),
#  (('कुं', 'व'), 39),
#  (('ब', 'रा'), 39),
#  (('फ', 'र'), 39),
#  (('र', 'च'), 39),
#  (('वा', 'ल'), 39),
#  (('ह', 'रू'), 39),
#  (('ज', 'सि'), 39),
#  (('ल', 'प'), 39),
#  (('न', 'अ'), 39),
#  (('ता', 'रा'), 38),
#  (('म', 'ले'), 38),
#  (('य', 'रा'), 38),
#  (('वि', 'न्द्र'), 38),
#  (('<S>', 'शो'), 38),
#  (('म', 'प'), 38),
#  (('य', 'क'), 38),
#  (('भू', 'ष'), 38),
#  (('शे', 'ष'), 38),
#  (('वी', '<E>'), 38),
#  (('ले', 'श्व'), 38),
#  (('म', 'ग'), 38),
#  (('वृ', 'ज'), 38),
#  (('मु', 'ल्ला'), 38),
#  (('न', 'ज'), 38),
#  (('सु', 'न'), 38),
#  (('<S>', 'ड'), 38),
#  (('र', 'वा'), 38),
#  (('<S>', 'सी'), 37),
#  (('म', 'दा'), 37),
#  (('म', 'नो'), 37),
#  (('ला', 'व'), 37),
#  (('ल', 'न'), 37),
#  (('ज्ञा', 'न'), 37),
#  (('ज', 'मी'), 37),
#  (('नू', 'र'), 37),
#  (('म', 'ज'), 37),
#  (('भ', 'र'), 37),
#  (('सो', 'न'), 37),
#  (('व', 'द'), 37),
#  (('ष', 'ण'), 37),
#  (('<S>', 'वं'), 37),
#  (('अ', 'क'), 37),
#  (('वं', 'श'), 37),
#  (('स', 'ई'), 37),
#  (('म्म', 'न'), 37),
#  (('<S>', 'घु'), 37),
#  (('वा', 'सी'), 37),
#  (('न्ता', '<E>'), 37),
#  (('तू', '<E>'), 37),
#  (('ब', 'क्स'), 37),
#  (('नं', 'द'), 37),
#  (('ग', 'दी'), 36),
#  (('व', 'ध'), 36),
#  (('कि', 'शु'), 36),
#  (('ल', 'ब'), 36),
#  (('ध', 'र्म'), 36),
#  (('दे', 'श'), 36),
#  (('<S>', 'शै'), 36),
#  (('ले', 'न्द्र'), 36),
#  (('वा', 'वू'), 36),
#  (('अ', 'ल'), 36),
#  (('<S>', 'मी'), 36),
#  (('ली', 'म'), 36),
#  (('त', 'र'), 36),
#  (('पे', 'न्द्र'), 36),
#  (('<S>', 'पी'), 36),
#  (('<S>', 'भि'), 36),
#  (('दू', '<E>'), 36),
#  (('गु', 'रू'), 36),
#  (('आ', 'ल'), 36),
#  (('बु', 'ल'), 36),
#  (('ब', 'ख्श'), 36),
#  (('कै', 'ला'), 35),
#  (('व', 'ना'), 35),
#  (('ख', 'रा'), 35),
#  (('व', 'च'), 35),
#  (('ला', 'स'), 35),
#  (('र', 'दे'), 35),
#  (('धी', 'र'), 35),
#  (('टी', '<E>'), 35),
#  (('<S>', 'पि'), 35),
#  (('री', 'सिं'), 35),
#  (('डी', '<E>'), 35),
#  (('रू', 'द्दी'), 35),
#  (('के', '<E>'), 35),
#  (('न', 'च'), 35),
#  (('क', 'रू'), 35),
#  (('<S>', 'बो'), 35),
#  (('दु', 'ल'), 35),
#  (('ध', '<E>'), 34),
#  (('ल', 'ता'), 34),
#  (('ला', 'ब'), 34),
#  (('म', 'नी'), 34),
#  (('सा', 'ग'), 34),
#  (('ला', 'म'), 34),
#  (('<S>', 'धी'), 34),
#  (('<S>', 'कं'), 34),
#  (('सी', 'र'), 34),
#  (('उ', 'म'), 34),
#  (('ज', 'व'), 34),
#  (('न', 'प'), 34),
#  (('वू', '<E>'), 34),
#  (('सि', 'र'), 34),
#  (('प', 'सि'), 34),
#  (('<S>', 'खै'), 34),
#  (('<S>', 'प्रा'), 34),
#  (('<S>', 'चं'), 34),
#  (('जु', 'ल'), 34),
#  (('<S>', 'धु'), 34),
#  (('ज', 'कु'), 33),
#  (('<S>', 'शं'), 33),
#  (('य', 'प्र'), 33),
#  (('वी', 'रे'), 33),
#  (('ष्ण', '<E>'), 33),
#  (('स', 'मु'), 33),
#  (('सु', 'म'), 33),
#  (('ज', 'वा'), 33),
#  (('<S>', 'रं'), 33),
#  (('र', 'सी'), 33),
#  (('वे', 'द'), 33),
#  (('<S>', 'जं'), 33),
#  (('<S>', 'सौ'), 33),
#  (('ल', 'कि'), 33),
#  (('ज', 'मा'), 33),
#  (('रं', 'ग'), 33),
#  (('दि', 'ल'), 33),
#  (('या', 'र'), 33),
#  (('न्दी', '<E>'), 33),
#  (('म', 'तु'), 33),
#  (('उ', 'मा'), 32),
#  (('सु', 'न्द'), 32),
#  (('ल', 'क्ष्मी'), 32),
#  (('ल्ल', 'न'), 32),
#  (('म', 'ता'), 32),
#  (('<S>', 'गौ'), 32),
#  (('वि', 'ला'), 32),
#  (('र', 'ख'), 32),
#  (('मु', 'ने'), 32),
#  (('न', 'म'), 32),
#  (('स', 'क'), 32),
#  (('वि', 'हा'), 32),
#  (('या', 'ज'), 32),
#  (('व', 'ब'), 32),
#  (('श', 'ब'), 32),
#  (('व', 'न्ती'), 32),
#  (('रू', 'ल्ला'), 32),
#  (('<S>', 'खि'), 32),
#  (('दु', 'ला'), 31),
#  (('ज', 'पा'), 31),
#  (('र', 'फी'), 31),
#  (('अ', 'त'), 31),
#  (('बं', 'श'), 31),
#  (('<S>', 'ऊ'), 31),
#  (('व', 'स'), 31),
#  (('रू', 'द'), 31),
#  (('<S>', 'ध्रु'), 31),
#  (('हु', 'सै'), 31),
#  (('सू', '<E>'), 31),
#  (('<S>', 'फै'), 31),
#  (('न', 'दे'), 31),
#  (('न', 'स'), 31),
#  (('बु', 'ल्ला'), 31),
#  (('<S>', 'धू'), 31),
#  (('द', 'खां'), 31),
#  (('दि', 'ने'), 30),
#  (('व', 'प्र'), 30),
#  (('<S>', 'छे'), 30),
#  (('<S>', 'यो'), 30),
#  (('स', 'ती'), 30),
#  (('मू', 'र'), 30),
#  (('मा', 'ल'), 30),
#  (('आ', 'न'), 30),
#  (('प्र', 'भा'), 30),
#  (('न', 'कू'), 30),
#  (('सु', 'क'), 30),
#  (('य', 'कु'), 30),
#  (('न', 'जी'), 30),
#  (('ने', 'क'), 30),
#  (('श', 'प्र'), 30),
#  (('श', 'ना'), 30),
#  (('टू', '<E>'), 30),
#  (('त्त', 'म'), 30),
#  (('हा', 'ल'), 30),
#  (('क', 'व'), 30),
#  (('छो', 'ट'), 30),
#  (('क', 'री'), 30),
#  (('<S>', 'लु'), 30),
#  (('<S>', 'खा'), 30),
#  (('प', 'त्ती'), 30),
#  (('थ', 'सिं'), 30),
#  (('मु', 'नि'), 30),
#  (('र', 'ग'), 30),
#  (('न्नि', 'शा'), 30),
#  (('म', 'भ'), 29),
#  (('ग', 'या'), 29),
#  (('न', 'य'), 29),
#  (('व', 'ला'), 29),
#  (('च', 'ल'), 29),
#  (('या', 'व'), 29),
#  (('सा', 'र'), 29),
#  (('सो', 'म'), 29),
#  (('इ', 'क'), 29),
#  (('र', 'वे'), 29),
#  (('प', 'रा'), 29),
#  (('<S>', 'फि'), 29),
#  (('ग', 'म'), 29),
#  (('ले', 'स'), 29),
#  (('नि', 'र'), 29),
#  (('श', 'ह'), 29),
#  (('त', 'कु'), 29),
#  (('मे', 'न्द्र'), 29),
#  (('ब्र', 'ह'), 29),
#  (('ज', 'ल'), 29),
#  (('मु', 'द'), 29),
#  (('ता', 'न'), 29),
#  (('ल', 'अ'), 29),
#  (('रा', 'मे'), 28),
#  (('<S>', 'दू'), 28),
#  (('ब', 'न'), 28),
#  (('बृ', 'जे'), 28),
#  (('सु', 'भा'), 28),
#  (('सो', 'ह'), 28),
#  (('स', 'ली'), 28),
#  (('स', 'व'), 28),
#  (('<S>', 'चौ'), 28),
#  (('ई', 'श्व'), 28),
#  (('वि', 'श'), 28),
#  (('लो', 'क'), 28),
#  (('ना', 'म'), 28),
#  (('वि', 'शु'), 28),
#  (('त्त', 'र'), 28),
#  (('बि', 'ज'), 28),
#  (('इ', 'या'), 28),
#  (('रु', 'प'), 28),
#  (('कु', 'व'), 28),
#  (('द', 'म'), 28),
#  (('ची', '<E>'), 28),
#  (('बा', '<E>'), 28),
#  (('स', 'रू'), 28),
#  (('ल', 'प्र'), 28),
#  (('ली', 'मु'), 28),
#  (('<S>', 'टि'), 28),
#  (('नि', 'शां'), 28),
#  (('दी', 'श'), 27),
#  (('<S>', 'ही'), 27),
#  (('हे', 'श'), 27),
#  (('दे', 'वे'), 27),
#  (('मु', 'ना'), 27),
#  (('शी', 'ला'), 27),
#  (('ग', 'ज'), 27),
#  (('ल', 'दे'), 27),
#  (('कु', 'र'), 27),
#  (('रो', 'ज'), 27),
#  (('ग', 'द'), 27),
#  (('गी', 'र'), 27),
#  (('<S>', 'हं'), 27),
#  (('ग', 'ब'), 27),
#  (('ब', 'स'), 27),
#  (('वे', 'श'), 27),
#  (('ह', 'व'), 27),
#  (('ने', 'न्द्र'), 27),
#  (('कु', 'श'), 27),
#  (('<S>', 'यु'), 27),
#  (('<S>', 'ऋ'), 27),
#  (('रू', 'क'), 27),
#  (('शू', '<E>'), 27),
#  (('य', 'त'), 27),
#  (('श', 'सि'), 27),
#  (('र्र', 'ह'), 27),
#  (('अ', 'नि'), 26),
#  (('धे', 'श'), 26),
#  (('ग', 'ने'), 26),
#  (('पू', 'र'), 26),
#  (('<S>', 'चे'), 26),
#  (('ब', 'च'), 26),
#  (('न', 'न्ह'), 26),
#  (('न', 'द'), 26),
#  (('ख', 'ली'), 26),
#  (('वि', 'द्या'), 26),
#  (('ना', 'र'), 26),
#  (('रा', 'धा'), 26),
#  (('धा', '<E>'), 26),
#  (('र', 'सा'), 26),
#  (('ष', 'कु'), 26),
#  (('शा', 'द'), 26),
#  (('ख', 'ई'), 26),
#  (('हि', 'द'), 26),
#  (('<S>', 'वै'), 26),
#  (('जा', 'द'), 26),
#  (('ही', 'म'), 26),
#  (('वि', 'र'), 26),
#  (('ह', 'सी'), 26),
#  (('न', 'ब'), 26),
#  (('हु', 'से'), 26),
#  (('मे', 'ह'), 26),
#  (('क', 'सिं'), 26),
#  (('दु', 'ल्ला'), 26),
#  (('<S>', 'नु'), 26),
#  (('र', 'उ'), 26),
#  (('ल', 'नि'), 26),
#  (('व', 'धे'), 25),
#  (('र', 'जू'), 25),
#  (('रे', 'ला'), 25),
#  (('म', 'वी'), 25),
#  (('म', 'वि'), 25),
#  (('ला', 'ख'), 25),
#  (('मु', 'र'), 25),
#  (('सु', 'मे'), 25),
#  (('हि', 'र'), 25),
#  (('<S>', 'शौ'), 25),
#  (('रा', 'र'), 25),
#  (('प', 'च'), 25),
#  (('ह', 'जा'), 25),
#  (('ने', 'श्व'), 25),
#  (('क', 'बा'), 25),
#  (('ब', 'ज'), 25),
#  (('फ', 'ते'), 25),
#  (('श', 'शि'), 25),
#  (('ही', 'द'), 25),
#  (('ह', 'ल'), 25),
#  (('हा', '<E>'), 25),
#  (('कु', 'म'), 25),
#  (('मु', 'कु'), 25),
#  (('द', 'रू'), 25),
#  (('<S>', 'छु'), 25),
#  (('द', 'सिं'), 25),
#  (('ड़ी', '<E>'), 25),
#  (('रु', 'ल'), 25),
#  (('म', 'खां'), 25),
#  (('रा', 'धे'), 24),
#  (('हे', 'न्द्र'), 24),
#  (('वि', 'श्व'), 24),
#  (('ही', 'रा'), 24),
#  (('या', 'रा'), 24),
#  (('व', 'कु'), 24),
#  (('धा', 'र'), 24),
#  (('उ', 'मे'), 24),
#  (('कृ', 'पा'), 24),
#  (('शी', 'त'), 24),
#  (('य', 'ब'), 24),
#  (('रि', '<E>'), 24),
#  (('हे', 'म'), 24),
#  (('धू', '<E>'), 24),
#  (('सी', 'म'), 24),
#  (('अ', 'श'), 24),
#  (('गे', 'श'), 24),
#  (('य', 'सिं'), 24),
#  (('ल', 'दा'), 24),
#  (('ह', 'मी'), 24),
#  (('ज', 'ही'), 24),
#  (('हू', '<E>'), 24),
#  (('य', 'श'), 24),
#  (('ट', 'न'), 24),
#  (('या', 'न'), 24),
#  (('<S>', 'पृ'), 24),
#  (('स', 'मा'), 24),
#  (('णी', '<E>'), 24),
#  (('ल', 'ल'), 24),
#  (('र', 'दी'), 24),
#  (('न्ने', '<E>'), 24),
#  (('की', 'र'), 24),
#  (('कि', '<E>'), 24),
#  (('फ', 'त'), 24),
#  (('स', 'मी'), 24),
#  (('नि', 'क'), 24),
#  (('री', 'सि'), 24),
#  (('बो', 'ध'), 24),
#  (('गु', 'न'), 24),
#  (('अ', 'ल्ला'), 24),
#  (('सा', 'म'), 24),
#  (('<S>', 'झा'), 24),
#  (('<S>', 'चा'), 24),
#  (('आ', '<E>'), 24),
#  (('ल', 'र'), 24),
#  (('ब', 'अ'), 24),
#  (('नी', 'ल'), 23),
#  (('यो', 'गे'), 23),
#  (('ती', 'श'), 23),
#  (('नी', 'रा'), 23),
#  (('म', 'ति'), 23),
#  (('वि', 'न'), 23),
#  (('द', 'र्श'), 23),
#  (('ना', 'गे'), 23),
#  (('भी', 'म'), 23),
#  (('<S>', 'फे'), 23),
#  (('ई', 'ला'), 23),
#  (('इ', 'न्द'), 23),
#  (('घु', 'र'), 23),
#  (('य', 'ना'), 23),
#  (('सं', 'त'), 23),
#  (('रे', 'न्द'), 23),
#  (('ज्ज', 'न'), 23),
#  (('वि', 'ष्णु'), 23),
#  (('ता', 'ब'), 23),
#  (('<S>', 'भै'), 23),
#  (('अ', 'ग'), 23),
#  (('बि', 'न्द'), 23),
#  (('ह', 'की'), 23),
#  (('रा', 'जु'), 23),
#  (('ना', 'य'), 23),
#  ...]

# %%
chars_ls = [list(name) for name in names]
chars = []
for ls in chars_ls:
    chars += ls

# %%
purna_virama = '।'
chars = sorted(list(set(chars)))
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi[purna_virama] = 0
itos = {i:s for s,i in stoi.items()}
unique_syallable_count = len(stoi)

# %%
# GOAL: maximize likelihood of the data w.r.t. model parameters (statistical modeling)
# equivalent to maximizing the log likelihood (because log is monotonic)
# equivalent to minimizing the negative log likelihood
# equivalent to minimizing the average negative log likelihood

# log(a*b*c) = log(a) + log(b) + log(c)

# %%
# --------- !!! OPTIMIZATION !!! yay, but this time actually --------------

# %%
import jax
import jax.numpy as jnp
from jax import random

# %%
# create the dataset
xs, ys = [], []
for w in names:
  chs = [purna_virama] + list(w) + [purna_virama]
  for ch1, ch2 in zip(chs, chs[1:]):
    ix1 = stoi[ch1]
    ix2 = stoi[ch2]
    xs.append(ix1)
    ys.append(ix2)
xs = jnp.array(xs)
ys = jnp.array(ys)
num = xs.shape[0]
print('number of examples: ', num)
# Out:
# number of examples:  161660

# %%
import torch
import torch.nn.functional as F

# finally, sample from the 'neural net' model
def generate_names(W: torch.tensor, name_count: int = 5) -> None:
    g = torch.Generator().manual_seed(2147483647)
    for i in range(name_count):
        out = []
        ix = 0
        while True:
            xenc = F.one_hot(torch.tensor([ix]), num_classes=unique_syallable_count).float()
            logits = xenc @ W # predict log-counts
            counts = logits.exp() # counts, equivalent to N
            p = counts / counts.sum(1, keepdims=True) # probabilities for next character
            ix = torch.multinomial(p, num_samples=1, replacement=True, generator=g).item()
            out.append(itos[ix])
            if ix == 0:
                break
        print(''.join(out))

# %%
jax.nn.one_hot(xs, num_classes=unique_syallable_count).shape
# Out:
# (161660, 1296)

# %%
from jax import grad, jit
import jax.numpy as jnp
import numpy as np


# Define the loss function
def loss_fn(W, xs, ys):
    xenc = jax.nn.one_hot(xs, num_classes=unique_syallable_count)
    logits = xenc @ W
    counts = jnp.exp(logits)
    probs = counts / jnp.sum(counts, axis=1, keepdims=True)
    loss = -jnp.mean(jnp.log(probs[jnp.arange(num), ys])) + 0.01*(jnp.power(W, 2)).mean()
    return loss

# Define the update function
@jit
def update(W, xs, ys):
    grad_fn = jit(grad(loss_fn))
    loss = loss_fn(W, xs, ys)
    dW = grad_fn(W, xs, ys)
    W -= 50 * dW
    return W, loss

# %%
from jax_smi import initialise_tracking
initialise_tracking()

seed = 2147483647
key = random.PRNGKey(seed)
key, subkey = random.split(key)

# generate random numbers with mean 0 and standard deviation 1
W = random.normal(subkey, (unique_syallable_count, unique_syallable_count))
for k in range(10000):
    W, loss = update(W, xs, ys)
    
    if k%100 == 0:
        print(f"At step: {k}, loss: {loss}")
        W_hat = np.asarray(W)
        generate_names(W_hat, 5)
# Out:
# At step: 0, loss: 7.715683460235596
# म्पीवेर्कक्शूक्षीसैष्काक्सेभौम्हम्भुपँसौमूंव्राल्टहाँप्तैद्धोव्यक्षन्हॅूल्मीन्टाब्बूर्टच्छुध्दिल्बेछॅदिछाँऋृम्वान्साब्दुस्सिन्हूर्रूहौच्चोल्कामूँधूकौर्बाङीझूर्योन्कूभंडेद्वेच्छाणात्येड्डूशून्डेठद्दिठिन्डय्यर्तमन्टाव्तेन्ह
# At step: 600, loss: 4.040939807891846
# रंल्पुरौक्खीक्माष्ठष्मक्रांम्मिय्यूम्मान्तष्टिम्माव्लूलांहादुरव।
# बैल्लूगृप्पुलू।
# निशा।
# ती।
# अली।
# At step: 700, loss: 3.9769160747528076
# रवर।
# इसश्म्भख्त्याम्मोरैम्बेन्ध्यस्जिम्रव्राल्टहाँप्तेद्योवाँक्शून्सल्तीन्गूप्रिर्बिचाधेश।
# ति।
# अली।
# मसूरबहृच्चेल्थूम्दना।
# At step: 800, loss: 3.9236032962799072
# रवर।
# इसश्नूखेम्बूम्मुमीनसिंहरमेह।
# दैश।
# बैल्लनकूधिग्रिद्रोल्पूचिंत्रुछिंआंम्दपीब्रिष्यंन्सार्मूहोचिंल्टूमौन्गूक्खीर्फच्चाट्ठुर्नानुम्भिढ़ीनृजागेन्द्र।
# शिवचोद्वोडूँनुर्चिर्ताम्मुन्जुव्दुन्युद्दम्दढित्माथ्थूहरिप्तिल्तिअॅत्रीचौख्याश्वेआैग्गूछीन्टीन्हाँस्सूलौंगांद्यपैनूतांज्वाफौशाचैल्पुम्भिणीकुॅम्बिऱद्विर्गाआैच्चट्टोक्सीत्थीक्तीखॉक्सेरींन्तिप्रांबांनोख्खाकौष्ठिर्राश्लोव्यगापृन्यूनृप्रिंर्शील्लोर्तिष्टिच्चुडींहित।
# At step: 900, loss: 3.878178119659424
# रवर।
# इसश्तक्षिमूंम्पीम्भन्यूसुमेश्वरीसिंह।
# शिछीपंल्जान्कूफूल।
# निशा।
# ति।
# At step: 1000, loss: 3.8388328552246094
# रवंश।
# इसशू।
# रनाथ।
# सुमेश्वरीसिंह।
# शिछैपंल्केन्जब्दुल।
# At step: 1100, loss: 3.804133415222168
# रवाल।
# इसव्वेक्सामृम्मोम्हन्नीव्तेमोहम्मसाँपँत्सश्त्याक्ष्मीन्हैल्कून्चीफिरे।
# निशा।
# ताँच्छूएर्शीप्याबोश्वेन्नुर्हहिडँूल्जाभ्याधोक्केर्फचौछॉर्मुध्दूभौडुद्वुचित।
# जिलेन्द्र।
# At step: 1200, loss: 3.773343324661255
# रवाल।
# इसव्वक्सीमोहदेवसिंहरमेह।
# देव।
# बेलालकुमाघेध्रूल्पाचोत्ताचौउमारतीलालप्रसुखरामती।
# ल।
# At step: 1300, loss: 3.745720148086548
# रवाल।
# आसव्लूक्ष्मीम्तऱम्मोन्यस्कूम्पूशोरस्फापॉत्राव्वीक्शून्सल्तीन्गीफूल।
# निशा।
# ता।
# अली।
# At step: 1400, loss: 3.720688819885254
# रवाल।
# इसव्यौखूंम्रम्यायिन्नुसैनलालह।
# देव।
# बेलालकीर।
# निशा।
# At step: 1500, loss: 3.6980278491973877
# रवाल।
# इसव्दखंम्तऱम्मोन्यस्कूम्पूशैलेस्जिप्टद्दूर्षिक्शून्सल्तीन्गीफूल।
# निशा।
# ता।
# अली।
# At step: 1600, loss: 3.6772756576538086
# रवाल।
# इसवेचून्धम्त्याम्भेन्हूँस्नेम्म्दशेषस्तिन्सोद्दीन।
# बेलालकीर।
# निशा।
# ता।
# At step: 1700, loss: 3.6582536697387695
# रवाल।
# इसवुखिलालढुन्मस्दीम्दव्राल्टीहान।
# शिज्जुन्साल्दान्टूद्दूफ्तेचिनराजगजोऋषिप्तेफ्फूसृन्धेर्धस्सुच्छेल्तीम्ताध्नक्टूर्मोच्चोडँूर्बनूपचन्द।
# जाझाद्दर्बेन्छोज्जूजैड्डीन्जयपाल।
# समज्जन।
# At step: 1800, loss: 3.6407113075256348
# रवाल।
# इसवी।
# रनाथ।
# सुमेश्वरीसिंह।
# शिज्जोन्सुल्पूद्रेप्यारे।
# At step: 1900, loss: 3.6245124340057373
# रवाल।
# इसवी।
# रनाथ।
# सुमेश्वरीसिंह।
# शिज्योन्यालिंन्गाबलू।
# At step: 2000, loss: 3.6094517707824707
# रवाल।
# इसवी।
# रनाथ।
# सुमेश्वरीसिंह।
# शिज्यापीरक्खातृर्बिचानराजगजौऋृम्वान्सूपेश्मन्दीफाहादुलचंद।
# At step: 2100, loss: 3.5954301357269287
# रवाल।
# इसवी।
# रनाथ।
# सुमेश्वरीसिंह।
# शिझुपूरौंन्झूब्यार्शढ़द्माल्यचौणाघ्याऋषिप्टब्दूसादम्मसेठूमोह।
# At step: 2200, loss: 3.5823395252227783
# रवाल।
# इसवी।
# रनाथ।
# सुमेश्वरीसिंह।
# शिझीन्मुर्षनौम्म्दर्मची।
# At step: 2300, loss: 3.5700953006744385
# रवाल।
# इसवी।
# रनाथ।
# सुमेश्वरीसिंह।
# शिझून्हॉल्टीनाथ।
# At step: 2400, loss: 3.558562994003296
# रवाल।
# इसविघाम्म्दयन।
# सुमेश्वरीसिंह।
# शिझौन्सुल्पूद्रोबँर्वेडॅूधुलौंङीत्थाच्युउमारतावनीब्वहू।
# विम्यान्गक्खिर्दच्छोझोर्बीन्चूब्दुल।
# At step: 2500, loss: 3.5476858615875244
# रवाल।
# इसविघीम्दम्मद्दीनसिंहरमुह।
# देव।
# बेल।
# मर्मीग्रामविजगज्ञअौम्बुन्शुप्रीवू।
# At step: 2600, loss: 3.5373926162719727
# रवाल।
# इसविघेम्तेम्भिमोसाहदीपराव्दाबांत्रीधौंक्षिफीपँध्यानभँच्छूधांल्हीघित्रित्कओमनकुवंशरह।
# विम्मैनूीक्कुर्बछाँजीमती।
# जन।
# जाजुछेर्नान्डझीदीन।
# At step: 2700, loss: 3.5276894569396973
# रवाल।
# इसविघौम्तेम्भिमोसिहद्वूल्लूप्पुह्मन्नौद्दीन।
# बेल।
# मर्मुचैनराजगज्वाउमारतिल्टून्दाफास्सोघील्पीमूँधी।
# ल।
# At step: 2800, loss: 3.5184476375579834
# रवाल।
# इसविघ्याभाप्राबाबूषेमैल्लोर्भाहँप्तित्नीवैक्तिन्श्याल्दीनंदयकप्फलिकान्डैज।
# रण।
# सुन्दाफ्फाहॅग्रामबद्रीकुंवकुन्झूर्यांन्कीमोधुन्द्रेड्डाठ्ठूत्थूढुवाँन्चीझेद्रीटांन्टीर्जन्ध्यांम्भान्टाव्तेन्हू।
# र।
# At step: 2900, loss: 3.5096397399902344
# रवाल।
# आेसुल्काक्ष्मीब्दूम्हम्नन्द्रोसैनलालह।
# देव।
# बेल।
# मर्मीग्रामविजगझाइंम्तपृथ्वीष्णण।
# At step: 3000, loss: 3.5012991428375244
# रवाल।
# इसविचन्द्रपाल।
# सुमेश्वरीसिंह।
# शिट्टुन्हूंल्फेन्गाफ्फार्बीच्छाधूराजगझुआेम्बून्हूंफौस्कान्हुर्माहुंचुम्भिभैप्योक्फर्धन।
# ल।
# At step: 3100, loss: 3.4933199882507324
# रवाल।
# आेसुलौखाँ।
# रामदेशबालियासमजला।
# बेल।
# मर्मचॉद्दाम्भन्हींतेज।
# At step: 3200, loss: 3.485705614089966
# रवाल।
# इसविचन्द्रपाल।
# सुमेश्वरीसिंह।
# शिट्टुन्हेलांधोंन्हाँर्बेच्चेधौल्लन।
# गिक्मम्बरतिल्दून्सोर्थस्सिजिंलच्चेनी।
# At step: 3300, loss: 3.478393793106079
# रवाल।
# आेसुलैक्षूम्पीयीभानसिंहरमुह।
# देव।
# बेल।
# मर्देघूनुल्ला।
# At step: 3400, loss: 3.471433162689209
# रवाल।
# इसविचन्द्रप्रसादलेशलालह।
# देव।
# बेल।
# मर्पघ्याद्दर।
# At step: 3500, loss: 3.464754104614258
# रवाल।
# इसविचन्द्रपोमुँन्धेसैनंबसहान।
# शिट्ठीन्हेलांधोंन्हाँर्बेच्चेधौल्फच्छद्देच्चोएवन्ती।
# सुन्दरह।
# विम्भीधी।
# At step: 3600, loss: 3.458306312561035
# रवाल।
# इसविचन्द्रप्रसादलेशलालह।
# देव।
# बेल।
# मर्री।
# At step: 3700, loss: 3.452122688293457
# रवाल।
# इसविचन्द्रप्रसादलेशलालह।
# देव।
# बेल।
# मर्री।
# At step: 3800, loss: 3.446176052093506
# रवाल।
# इसविचन्द्रप्रसादलू।
# सरीसिंह।
# शिडथचिनकाश।
# निशा।
# At step: 3900, loss: 3.440488815307617
# रवाल।
# इसविचन्द्रप्रसादलू।
# सरीसिंह।
# शिठोन्यल्हेन्कीबूीर्वङूधर्टछिंढ़ागा।
# रण।
# At step: 4000, loss: 3.434950351715088
# रवाल।
# इसविचन्द्रपियाग्गव्रेमीरूर्लीस्हापंचर।
# बेल।
# मर्बाग्रन्जूील्ल्नघ्नतुंछाऋृम्वान्सोप्पीस्तून्हांर्पहू।
# विम्पूद्दुक्छेर्देचेतरकर।
# At step: 4100, loss: 3.429619550704956
# रवंश।
# इसविचन्द्रप्रसादलेशलालह।
# देव।
# बेल।
# मर्बच्ची।
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 11
#       9 W = random.normal(subkey, (unique_syallable_count, unique_syallable_count))
#      10 for k in range(10000):
# ---> 11     W, loss = update(W, xs, ys)
#      13     if k%100 == 0:
#      14         print(f"At step: {k}, loss: {loss}")
#
# KeyboardInterrupt:
